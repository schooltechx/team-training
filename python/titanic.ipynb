# %% [markdown]
# ## Titanic Dataset
#
# ตัวอย่าง Dataset เป็นรายชื่อผู้โดยสารของเรื่อไททานิก สามารถใช้เพื่อวิเคราะห์ว่าผู้รอดหรือเสียขีวิตมีคุณสมบัติใดเกี่ยวข้อบ้าง เช่น อายุ เพศ ชนิดของตั๋ว

# %%
# Other environment(not colab) uncomment this line
# %pip install pandas matplotlib ipywidgets
# %pip install ydata-profiling

# %%
import pandas as pd
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# titanic = pd.read_csv('./titanic.csv')

# %% [markdown]
# ตรวจสอบข้อมูลสถิติเบื้องต้น

# %%
titanic.describe() # อธิบายข้อมูลเชิงสถิติของ DataFrame

# %% [markdown]
# ดูข้อมูล

# %%
titanic.head(5)    # try titanic.tail(5)

# %% [markdown]
# ใช้ ydata_profiling ช่วยวิเคราะห์ข้อมูล

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(titanic, title="Pandas Profiling Report", explorative=True)
# profile.to_file("titanic_report.html")  # Save the report to an HTML file
profile
